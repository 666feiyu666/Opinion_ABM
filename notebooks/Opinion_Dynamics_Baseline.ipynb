# %% [markdown]
# # Opinion Dynamics Baseline
#
# This notebook reuses the shared experiment helpers in `experiments/base.py` so the baseline script, notebook, and saved outputs stay aligned.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

cwd = Path.cwd().resolve()
PROJECT_ROOT = cwd if (cwd / 'main.py').exists() else cwd.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from config import DEFAULT_SEED
from experiments.base import load_baseline_outputs, run_baseline_experiment
from visualization import plot_final_opinion_distribution, plot_network_and_homophily, plot_time_series_summaries

# %%
RUN_BASELINE = True

if RUN_BASELINE:
    baseline_results = run_baseline_experiment(
        seed=DEFAULT_SEED,
        output_dir=PROJECT_ROOT / 'outputs' / 'baseline',
    )
else:
    baseline_results = None

baseline_outputs = load_baseline_outputs(PROJECT_ROOT / 'outputs' / 'baseline')
display(baseline_outputs['history_df'].tail())
display(baseline_outputs['agents_df'].head())
# Out:
# D:\ProgramScripts\Opinion_ABM\visualization.py:184: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.tight_layout()
# D:\ProgramScripts\Opinion_ABM\experiments\base.py:537: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.savefig(figure_paths["opinion_leaders"], dpi=150, bbox_inches="tight")
#     potential_originators  actual_creators  constructive_posts  toxic_posts  \
# 45                    189              140                  74           66
# 46                    193              156                  71           85
# 47                    184              142                  53           89
# 48                    191              155                  70           85
# 49                    191              136                  55           81
#
#     support_posts  oppose_posts  avg_exposure_size  mean_opinion  std_opinion  \
# ...

# %%
if baseline_results is not None:
    fig, _ = plot_time_series_summaries(baseline_results['history_df'])
    plt.show()

    fig, _ = plot_final_opinion_distribution(baseline_results['agents'], params=baseline_results['params'])
    plt.show()

    fig, _ = plot_network_and_homophily(baseline_results['G_updated'], baseline_results['pos'])
    plt.show()
else:
    print('Set RUN_BASELINE = True to regenerate the baseline figures in this notebook.')
