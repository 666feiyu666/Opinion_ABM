# %% [markdown]
# # Phase 1 Tolerance Sweep
#
# Notebook workflow for the Monte Carlo baseline sweep over `theta_T`.

# %%
from pathlib import Path
import os
import sys

import matplotlib.pyplot as plt
from IPython.display import display

os.environ.setdefault("MPLCONFIGDIR", "/tmp/opinion_abm_mpl")

cwd = Path.cwd().resolve()
PROJECT_ROOT = cwd if (cwd / 'main.py').exists() else cwd.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from experiments.run_phase1_tolerance_sweep import run_phase1_experiment
from utils import project_path
from visualization import (
    build_tolerance_sweep_notebook_table,
    load_tolerance_sweep_outputs,
    plot_final_opinion_heatmap,
    plot_tolerance_sweep_curves,
)

# %%
output_subdir = "phase1_tolerance_sweep"
run_phase1_experiment(rounds=50, seeds=20, workers=4, output_subdir=output_subdir)

frames = load_tolerance_sweep_outputs(project_path("outputs", output_subdir))
sweep_raw_df = frames["sweep_raw_df"]
sweep_summary_df = frames["sweep_summary_df"]
opinion_samples_df = frames["opinion_samples_df"]

display(build_tolerance_sweep_notebook_table(sweep_summary_df))
# Out:
#  tolerance_threshold  extremist_ratio_mean  opinion_variance_mean  moderate_ratio_mean  mean_abs_opinion_mean
#               0.0000                0.6291                 0.5971               0.1149                 0.7219
#               0.1000                0.4604                 0.4362               0.3738                 0.5311
#               0.3000                0.3234                 0.3163               0.5798                 0.4302
#               0.5000                0.2152                 0.2620               0.4047                 0.4172
#               0.7000                0.1170                 0.2471               0.3769                 0.4211
#               0.9000                0.2239                 0.2645               0.3735                 0.4355
#               1.0000                0.2242                 0.2772               0.3785                 0.4420
# Saved Phase 1 tolerance sweep outputs to: /Users/paimon/projects/Opinion_ABM/outputs/phase1_tolerance_sweep
#    theta_T  extremist_mean  extremist_ci_low  extremist_ci_high  \
# 0      0.0         0.62915          0.621568           0.636732
# 1      0.1         0.46045          0.450572           0.470328
# 2      0.3         0.32340          0.315581           0.331219
# 3      0.5         0.21515          0.205711           0.224589
# 4      0.7         0.11700          0.109875           0.124125
# 5      0.9         0.22390          0.217304           0.230496
# 6      1.0         0.22415          0.217787           0.230513
#
#    variance_mean  variance_ci_low  variance_ci_high  moderate_mean  \
# 0       0.597061         0.591403          0.602719        0.11485
# 1       0.436181         0.427456          0.444907        0.37375
# 2       0.316294         0.308879          0.323710        0.57985
# 3       0.261972         0.254272          0.269673        0.40475
# 4       0.247116         0.241606          0.252626        0.37690
# 5       0.264510         0.259749          0.269270        0.37345
# 6       0.277178         0.272046          0.282309        0.37850
#
#    moderate_ci_low  moderate_ci_high  mean_abs_opinion  homophily_mean
# 0         0.109691          0.120009          0.721896        0.524701
# 1         0.364284          0.383216          0.531067        0.520382
# 2         0.570218          0.589482          0.430173        0.517782
# 3         0.395888          0.413612          0.417179        0.512922
# 4         0.368882          0.384918          0.421066        0.515049
# 5         0.364282          0.382618          0.435543        0.515904
# 6         0.369479          0.387521          0.442006        0.515241

# %%
fig, _ = plot_tolerance_sweep_curves(sweep_summary_df)
plt.show()
# Out:
# /var/folders/2q/0t_rsby13fd_4thd38dsf0hc0000gn/T/ipykernel_8023/106756667.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fig, _ = plot_final_opinion_heatmap(opinion_samples_df)
plt.show()
# Out:
# /var/folders/2q/0t_rsby13fd_4thd38dsf0hc0000gn/T/ipykernel_8023/938910741.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
sweep_summary_df[[
    "tolerance_threshold",
    "extremist_ratio_mean",
    "opinion_variance_mean",
    "moderate_ratio_mean",
    "mean_abs_opinion_mean",
    "homophily_ratio_mean",
]].sort_values("tolerance_threshold")
# Out:
#    tolerance_threshold  extremist_ratio_mean  opinion_variance_mean  \
# 0                  0.0               0.62915               0.597061
# 1                  0.1               0.46045               0.436181
# 2                  0.3               0.32340               0.316294
# 3                  0.5               0.21515               0.261972
# 4                  0.7               0.11700               0.247116
# 5                  0.9               0.22390               0.264510
# 6                  1.0               0.22415               0.277178
#
#    moderate_ratio_mean  mean_abs_opinion_mean  homophily_ratio_mean
# 0              0.11485               0.721896              0.524701
# 1              0.37375               0.531067              0.520382
# 2              0.57985               0.430173              0.517782
# 3              0.40475               0.417179              0.512922
# 4              0.37690               0.421066              0.515049
# 5              0.37345               0.435543              0.515904
# 6              0.37850               0.442006              0.515241
