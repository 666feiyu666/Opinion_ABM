# %% [markdown]
# # Integrated baseline simulation
#
# This notebook is the experiment-facing entry point for the integrated opinion-leader and platform scenario on `main`. The scenario package and configuration boundary are in place, but the scientific initialization, parameter values, observables, and run design are intentionally pending discussion.
#
# Retained model logic belongs in `opinion_model.scenarios.baseline`; this notebook will import and exercise that implementation rather than duplicate it.

# %%
from opinion_model.scenarios import baseline
